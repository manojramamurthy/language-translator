# %%
# !pip install python-docx
# Out:
# ...
#   Using cached python-docx-0.8.11.tar.gz (5.6 MB)
# ...
#   Using cached lxml-4.6.3-cp39-cp39-macosx_10_9_x86_64.whl (4.6 MB)
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=d9b4efca192044c23a24a8df9ec6663600613b3710ebece5e504a4112a89e0cb
#   Stored in directory: /Users/mramamurth003/Library/Caches/pip/wheels/83/8b/7c/09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# !pip install mtranslate
# Out:
# ...
#   Using cached google_cloud_translate-2.0.1-py2.py3-none-any.whl (90 kB)
# ...
#   Using cached google_api_core-1.31.2-py2.py3-none-any.whl (93 kB)
# ...
#   Using cached google_cloud_core-1.7.2-py2.py3-none-any.whl (28 kB)
# ...
#   Using cached protobuf-3.17.3-cp39-cp39-macosx_10_9_x86_64.whl (1.0 MB)
# ...
#   Using cached googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# ...
#   Using cached packaging-21.0-py3-none-any.whl (40 kB)
# ...
#   Using cached google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# ...
#   Using cached grpcio-1.39.0-cp39-cp39-macosx_10_10_x86_64.whl (3.9 MB)
# ...
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# ...
#   Using cached cachetools-4.2.2-py3-none-any.whl (11 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# ...

# %%
# !pip install google_trans_new
# Out:
# ...
#   Using cached google_trans_new-1.1.9-py3-none-any.whl (9.2 kB)
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# !pip install googletrans
# Out:
# ...
#      |████████████████████████████████| 55 kB 849 kB/s
# ...
#      |████████████████████████████████| 1.2 MB 895 kB/s
# ...
#      |████████████████████████████████| 42 kB 1.2 MB/s
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#      |████████████████████████████████| 58 kB 928 kB/s
# ...
#      |████████████████████████████████| 53 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 65 kB 1.6 MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15734 sha256=858d0081d957de78b4f8b61bb3411440e20c9ed63c2831288fec2360a21fbdd5
#   Stored in directory: /Users/mramamurth003/Library/Caches/pip/wheels/27/f3/32/d4859d40071f07a5df0ab6fdc0076e78a8a786625dde2b4b2f
# Successfully built googletrans
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.2
#     Uninstalling idna-3.2:
#       Successfully uninstalled idna-3.2
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
# ...

# %%
from googletrans import LANGUAGES

for lang in LANGUAGES:
    print(lang + '-' + LANGUAGES[lang])
# Out:
# af-afrikaans
# sq-albanian
# am-amharic
# ar-arabic
# hy-armenian
# az-azerbaijani
# eu-basque
# be-belarusian
# bn-bengali
# bs-bosnian
# bg-bulgarian
# ca-catalan
# ceb-cebuano
# ny-chichewa
# zh-cn-chinese (simplified)
# zh-tw-chinese (traditional)
# co-corsican
# hr-croatian
# cs-czech
# da-danish
# nl-dutch
# en-english
# eo-esperanto
# et-estonian
# tl-filipino
# fi-finnish
# fr-french
# fy-frisian
# gl-galician
# ka-georgian
# de-german
# el-greek
# gu-gujarati
# ht-haitian creole
# ha-hausa
# haw-hawaiian
# iw-hebrew
# he-hebrew
# hi-hindi
# hmn-hmong
# hu-hungarian
# is-icelandic
# ig-igbo
# id-indonesian
# ga-irish
# it-italian
# ja-japanese
# jw-javanese
# kn-kannada
# kk-kazakh
# km-khmer
# ko-korean
# ku-kurdish (kurmanji)
# ky-kyrgyz
# lo-lao
# la-latin
# lv-latvian
# lt-lithuanian
# lb-luxembourgish
# mk-macedonian
# mg-malagasy
# ms-malay
# ml-malayalam
# mt-maltese
# mi-maori
# mr-marathi
# mn-mongolian
# my-myanmar (burmese)
# ne-nepali
# no-norwegian
# or-odia
# ...

# %%
from googletrans import Translator
translator = Translator()
out = translator.translate('how are you', src='en', dest='ta')
print(out.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tv/5clwj80s1sxd1pz8zfpm2f9w0000gn/T/ipykernel_13139/1383333709.py in <module>
#       1 from googletrans import Translator
#       2 translator = Translator()
# ----> 3 out = translator.translate('how are you', src='en', dest='ta')
#       4 print(out.text)
#
# /usr/local/lib/python3.9/site-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.9/site-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
# ...

# %%
def docx_to_dict(name_of_file):
    from docx import Document
    from googletrans import Translator

    translator = Translator()

    out = translator.translate('how are you', dest='')

    docx_dict = {}
    document = Document(name_of_file)
    idx = 0
    for para  in doc.paragraphs:
        idx+=1
        if(len(para.text)>0):
            docx_dict[idx] = para.text
    return docx_dict

# %%
docx = docx_to_dict('manojkumar.docx')

# %%
docx
# Out:
# {22: 'Horoscope of Manoj Kumar R',
#  25: 'VÉxÉxÉÒ VÉx¨É ºÉÉèJªÉÉxÉÉÄ',
#  26: '´ÉvÉÇxÉÒ EÖ ±É ºÉÄ{ÉnÉÄ',
#  27: '{Én´ÉÒ {ÉÚ´ÉÇ {ÉÖhªÉÉxÉÉÄ Ê±ÉJªÉiÉä VÉx¨É {ÉÊÆjÉE É',
#  29: 'For the welfare of the mother and the child For the growth of the family happiness',
#  30: 'To follow the ancient virtuous practices The horoscope is written',
#  38: 'Name\t: Manoj Kumar R',
#  39: 'Sex\t: Male',
#  40: 'Date of Birth\t: 17 September, 1990 Monday',
#  41: 'Time of Birth (Hr.Min.Sec)\t: 04:00:00 PM Standard Time',
#  42: 'Time Zone (Hrs.Mins)\t: 05:30 East of Greenwich',
#  43: 'Place of Birth\t: Bargur R.F. Tamil Nadu India Longitude &Latitude (Deg.Mins)\t: 78.23 East, 12.31 North',
#  44: 'Ayanamsa\t: Chitra Paksha = 23 Deg. 43 Min. 52 Sec.',
#  45: 'Birth Star - Star Pada (Quarter)\t: Makha - 4',
#  46: 'Birth Rasi - Rasi Lord\t: Simha - Surya Lagna (Ascendant) - Lagna Lord\t: Makara - Sani',
#  47: 'Thidhi (Lunar Day)\t: Chathurdasi, Krishnapaksha',
# ...
